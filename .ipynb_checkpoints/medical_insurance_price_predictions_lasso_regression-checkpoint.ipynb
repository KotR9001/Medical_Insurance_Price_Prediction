# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
#Read in the Dataset
insurance_df = pd.read_csv('Medical_insurance.csv')
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
#Check for Null Values
insurance_df.loc[pd.isna(insurance_df).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

#Convert Categorical Values into Numerical Values
label_encoder_1 = LabelEncoder()
label_encoder_1.fit(insurance_df['sex'])
insurance_df['sex_encoded'] = label_encoder_1.transform(insurance_df['sex'])

label_encoder_2 = LabelEncoder()
label_encoder_2.fit(insurance_df['smoker'])
insurance_df['smoker_encoded'] = label_encoder_2.transform(insurance_df['smoker'])

label_encoder_3 = LabelEncoder()
label_encoder_3.fit(insurance_df['region'])
insurance_df['region_encoded'] = label_encoder_3.transform(insurance_df['region'])

insurance_df
# Out:
# C:\Users\bjros\Anaconda3\Lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
#       sex_encoded  smoker_encoded  region_encoded
# 0               0               1               3
# 1               1               0               2
# 2               1               0               2
# 3               1               0               1
# 4               1               0               1
# ...           ...             ...             ...
# 2767            0               0               2
# 2768            0               0               3
# 2769            1               1               1
# 2770            1               0               1
# 2771            1               0               3
#
# [2772 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(insurance_df[['age', 'sex_encoded', 'bmi', 'children', 'smoker_encoded', 'region_encoded']], insurance_df['charges'], train_size=0.7, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#       age  sex_encoded     bmi  children  smoker_encoded  region_encoded
# 1684   31            1  34.390         3               1               1
# 862    55            0  33.535         2               0               1
# 1992   27            0  25.175         0               0               0
# 889    57            1  33.630         1               0               1
# 1362   41            1  34.210         1               0               2
# ...   ...          ...     ...       ...             ...             ...
# 1638   54            1  34.210         2               1               2
# 1095   18            0  31.350         4               0               0
# 1130   39            0  23.870         5               0               2
# 1294   58            1  25.175         0               0               0
# 860    37            0  47.600         2               1               3
#
# [1940 rows x 6 columns]

# %%
X_test
# Out:
#       age  sex_encoded     bmi  children  smoker_encoded  region_encoded
# 1106   49            0  29.925         0               0               1
# 1321   62            1  26.695         0               1               0
# 2313   57            0  20.100         1               0               3
# 2274   22            1  39.500         0               0               3
# 1432   18            0  38.665         2               0               0
# ...   ...          ...     ...       ...             ...             ...
# 1900   39            1  28.300         1               1               3
# 647    40            0  23.370         3               0               0
# 2438   49            1  29.830         1               0               0
# 2452   48            1  37.290         2               0               2
# 1628   55            0  26.800         1               0               3
#
# [832 rows x 6 columns]

# %%
y_train
# Out:
# 1684    38746.35510
# 862     12269.68865
# 1992     3558.62025
# 889     11945.13270
# 1362     6289.75490
#            ...
# 1638    44260.74990
# 1095     4561.18850
# 1130     8582.30230
# 1294    11931.12525
# 860     46113.51100
# Name: charges, Length: 1940, dtype: float64

# %%
y_test
# Out:
# 1106     8988.15875
# 1321    28101.33305
# 2313    12032.32600
# 2274     1682.59700
# 1432     3393.35635
#            ...
# 1900    21082.16000
# 647      8252.28430
# 2438     9288.02670
# 2452     8978.18510
# 1628    35160.13457
# Name: charges, Length: 832, dtype: float64

# %%
#Create the Model
from sklearn.linear_model import Lasso

#Create a List of HyperParameter Values
alpha_params = [0.000001, 0.00001, 0.0001, 0.001, 0.1, 1]
max_iter_params = [1, 10, 100]
warm_start_params = [False, True]
selection_params = ['cyclic', 'random']


#Create a List for Data
data = []

#Loop through the Values in the HyperParameter List
for i in range(len(alpha_params)):
    for j in range(len(max_iter_params)):
        for k in range(len(warm_start_params)):
            for l in range(len(selection_params)):
                lasso_model = Lasso(alpha=alpha_params[i], max_iter=max_iter_params[j], warm_start=warm_start_params[k], selection=selection_params[l], random_state=42)

                #Train the Model
                lasso_model.fit(X_train, y_train)

                #Test the Model to Create Predictions
                y_predict = lasso_model.predict(X_test)

                #Test the Model Accuracy
                r2_score = lasso_model.score(X_test, y_test)

                #Test the Model for Overfitting
                #Found the Formula at https://stackoverflow.com/questions/51038820/how-to-calculated-the-adjusted-r2-value-using-scikit
                r2_adj_score = (1 - (1 - r2_score) * (1940 - 1) / (1940 - 6))

                data.append({'Alpha_Params': alpha_params[i], 'Max_Iter_Params': max_iter_params[j], 'Warm_Start_Params':warm_start_params[k], 'Selection_Params':selection_params[l], 'R^2_Score': r2_score, 'R^2_Adj_Score': r2_adj_score})

#Create Empty DataFrame to Store Parameter Values and Resultant R^2 & R^2 Adjusted Scores
tuning_df = pd.DataFrame(data=data, columns=['Alpha_Params', 'Max_Iter_Params', 'Warm_Start_Params', 'Selection_Params', 'R^2_Score', 'R^2_Adj_Score'])
#Create a Column to Store the Difference Between R^2 & R^2 Adjusted Values
tuning_df['R^2_Minus_R^2_Adjusted'] = tuning_df['R^2_Score'] - tuning_df['R^2_Adj_Score']

#Show When Done
print(f"Hyper Parameter Evaluation Done.")
# Out:
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.437e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.437e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.427e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.427e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.330e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.330e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.498e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Hyper Parameter Evaluation Done.
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.822e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.635e+08, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.635e+08, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.499e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.826e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.499e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.826e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %%
tuning_df
# Out:
#     Alpha_Params  Max_Iter_Params  Warm_Start_Params Selection_Params  \
# 0       0.000001                1              False           cyclic
# 1       0.000001                1              False           random
# 2       0.000001                1               True           cyclic
# 3       0.000001                1               True           random
# 4       0.000001               10              False           cyclic
# ..           ...              ...                ...              ...
# 67      1.000000               10               True           random
# 68      1.000000              100              False           cyclic
# 69      1.000000              100              False           random
# 70      1.000000              100               True           cyclic
# 71      1.000000              100               True           random
#
#     R^2_Score  R^2_Adj_Score  R^2_Minus_R^2_Adjusted
# 0    0.739940       0.739268                0.000672
# 1    0.714381       0.713642                0.000738
# 2    0.739940       0.739268                0.000672
# 3    0.714381       0.713642                0.000738
# 4    0.744218       0.743557                0.000661
# ..        ...            ...                     ...
# 67   0.744205       0.743544                0.000661
# 68   0.744205       0.743544                0.000661
# 69   0.744205       0.743544                0.000661
# 70   0.744205       0.743544                0.000661
# 71   0.744205       0.743544                0.000661
#
# [72 rows x 7 columns]

# %%
#Find the Highest r^2 Value
max_ = tuning_df.loc[tuning_df['R^2_Minus_R^2_Adjusted'] <= 0.10]['R^2_Score'].max()
#Print the Rows Containing the Highest r^2 Value
max_rows = tuning_df.loc[tuning_df['R^2_Score']==max_].reset_index(drop=True)
max_rows
# Out:
#    Alpha_Params  Max_Iter_Params  Warm_Start_Params Selection_Params  \
# 0      0.000001               10              False           random
# 1      0.000001               10               True           random
#
#    R^2_Score  R^2_Adj_Score  R^2_Minus_R^2_Adjusted
# 0   0.744218       0.743557                0.000661
# 1   0.744218       0.743557                0.000661

# %%
#Create Plot of Match-up Score r^2 Values for the DLC Characters vs Alpha Init Values

#Show a Wide View of All Data Points
plt.scatter(tuning_df['Alpha_Params'], tuning_df['R^2_Score'])
plt.xlabel('Alpha Initial Parameters')
plt.ylabel('Parameter R^2 Scores')
plt.title('Distribution of R^2 Scores vs Alpha Parameters')
plt.show()

# %%
#Show a Wide View of All Data Points
plt.scatter(tuning_df['Max_Iter_Params'], tuning_df['R^2_Score'])
plt.xlabel('Lambda Initial Parameters')
plt.ylabel('Parameter R^2 Scores')
plt.title('Distribution of R^2 Scores vs Max Iterations Parameters')
plt.show()

# %%
#Re-import the Lasso Model & Implement Parameter Values Associated with the Maximum R^2 Value, where the Difference
#Between the R^2 ^ R^2 Adjusted Values was <0.10
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=max_rows['Alpha_Params'][0], max_iter=max_rows['Max_Iter_Params'][0], warm_start=max_rows['Warm_Start_Params'][0], selection=max_rows['Selection_Params'][0])

#Train the Model
lasso_model.fit(X_train, y_train)

#Test the Model to Create Predictions
y_predict = lasso_model.predict(X_test)

#Test the Model Accuracy
r2_score = lasso_model.score(X_test, y_test)

#Test the Model for Overfitting
#Found the Formula at https://stackoverflow.com/questions/51038820/how-to-calculated-the-adjusted-r2-value-using-scikit
r2_adj_score = (1 - (1 - r2_score) * (1940 - 1) / (1940 - 6))
# Out:
# C:\Users\bjros\Anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+10, tolerance: 2.790e+07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %%
#Create a Test/Prediction DataFrame
prediction_df = pd.DataFrame({'Age': X_test['age'], 'Sex':X_test['sex_encoded'], 'BMI':X_test['bmi'], 'Children':X_test['children'], 'Smoker':X_test['smoker_encoded'], 'Region':X_test['region_encoded'], 'Actual_Charges': y_test, 'Predicted_Charges': y_predict})
prediction_df = prediction_df.reset_index(drop=True)
prediction_df['Index'] = prediction_df.index
prediction_df
# Out:
#      Age  Sex     BMI  Children  Smoker  Region  Actual_Charges  \
# 0     49    0  29.925         0       0       1      8988.15875
# 1     62    1  26.695         0       1       0     28101.33305
# 2     57    0  20.100         1       0       3     12032.32600
# 3     22    1  39.500         0       0       3      1682.59700
# 4     18    0  38.665         2       0       0      3393.35635
# ..   ...  ...     ...       ...     ...     ...             ...
# 827   39    1  28.300         1       1       3     21082.16000
# 828   40    0  23.370         3       0       0      8252.28430
# 829   49    1  29.830         1       0       0      9288.02670
# 830   48    1  37.290         2       0       2      8978.18510
# 831   55    0  26.800         1       0       3     35160.13457
#
#      Predicted_Charges  Index
# 0         10264.851089      0
# 1         36614.442474      1
# 2          9042.128867      2
# 3          5594.400995      3
# 4          6397.430286      4
# ..                 ...    ...
# 827       30656.735819    827
# 828        7753.323288    828
# 829       11059.226874    829
# 830       12975.370588    830
# 831       10642.919242    831
#
# [832 rows x 9 columns]

# %%
from sklearn import feature_selection
from sklearn.preprocessing import FunctionTransformer as transformer

# %%
#Print the Correlation Coefficients
print(f"The coefficients are: {lasso_model.coef_}")
print(f"The list of features and their corresponding coefficients are: {list(zip(X_test.columns, lasso_model.coef_))}")
lasso_coef_df = pd.DataFrame({'Features':X_test.columns, 'Coefficients':lasso_model.coef_})
lasso_coef_df
# Out:
# The coefficients are: [  258.03575072   -34.34294713   315.94953381   511.55460599
#  23702.80723479  -347.17933186]
# The list of features and their corresponding coefficients are: [('age', 258.0357507196883), ('sex_encoded', -34.34294713339112), ('bmi', 315.949533814224), ('children', 511.5546059930972), ('smoker_encoded', 23702.807234786487), ('region_encoded', -347.1793318600403)]
#          Features  Coefficients
# 0             age    258.035751
# 1     sex_encoded    -34.342947
# 2             bmi    315.949534
# 3        children    511.554606
# 4  smoker_encoded  23702.807235
# 5  region_encoded   -347.179332

# %%
#Check the Descriptive Statistics to See What Features Make the Best Predictors
import scipy.stats as stats

#ANOVA_results = stats.kruskal(test_linear_df_X1.dropna(axis=0), test_linear_df_Y1['Life expectancy '].dropna(axis=0))
ANOVA_results = feature_selection.f_regression(X_test.dropna(axis=0), y_test.dropna(axis=0))
#print(f"The selected features are: {selected_features.columns.values}")
#print(f"The F-values are: {ANOVA_results[0]}")
#print(f"The p-values are: {ANOVA_results[1]}")
F_regression_df = pd.DataFrame({'Selected_Features': X_train.columns.values, 'F-values': ANOVA_results[0], 'p-values': ANOVA_results[1]})
#F_regression_df = pd.DataFrame({'Selected_Features': transformer(feature_names_out = 'one-to-one').get_features_names_out(), 'F-values': ANOVA_results[0], 'p-values': ANOVA_results[1]})
#F_regression_df.sort_values('F-values', ascending=False)
F_regression_df1 = pd.merge(F_regression_df, lasso_coef_df, how = 'left', left_on = 'Selected_Features', right_on = 'Features')
F_regression_df2 = F_regression_df1.drop(columns='Features', axis = 1)
F_regression_df3 = F_regression_df2.dropna(subset=['F-values', 'p-values'])
F_regression_df4 = F_regression_df3.loc[F_regression_df3['p-values'] <= 0.05]
F_regression_df4.sort_values('Coefficients', ascending=False)
# Out:
#   Selected_Features     F-values       p-values  Coefficients
# 4    smoker_encoded  1339.840843  2.220614e-175  23702.807235
# 2               bmi    44.622718   4.375005e-11    315.949534
# 0               age    92.055264   9.578824e-21    258.035751
# 1       sex_encoded     4.242364   3.973857e-02    -34.342947

# %%
#Graph the Differences Between Actual & Predicted Charges

fig, ax = plt.subplots()
ax.plot(prediction_df['Index'], prediction_df['Actual_Charges'], color='blue', alpha=1.00, label='Actual Charges')
ax.fill_between(prediction_df['Index'], prediction_df['Actual_Charges'], 0, color='blue', alpha=.1)

ax.plot(prediction_df['Index'], prediction_df['Predicted_Charges'], color='red', alpha=1.00, label='Predicted Charges')
ax.fill_between(prediction_df['Index'], prediction_df['Predicted_Charges'], 0, color='red', alpha=.1)
ax.legend()

plt.xlabel('Record')
plt.ylabel('Insurance Price')
plt.rcParams.update({'font.size': 32})
plt.gcf().set_size_inches(32, 24)

plt.show()
